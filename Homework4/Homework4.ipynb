# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import Imputer
from sklearn.model_selection import KFold, train_test_split, GridSearchCV
from sklearn.metrics import roc_auc_score, confusion_matrix, accuracy_score
import lightgbm as lgb
import xgboost as xgb
import seaborn as sns
import gc
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
dataFrame = pd.read_csv("hmelq.csv")
dataFrame.head()
# Out:
#    bad   loan   mortdue     value   reason  job   yoj  derog  delinq   clage  \
# 0    0  81200   18834.0  108355.0  HomeImp  NaN  28.0    0.0     0.0  139.14
# 1    0  12600  103960.0  127384.0  DebtCon  NaN   2.0    0.0     0.0  129.02
# 2    0  18000   46865.0   61266.0  DebtCon  NaN   5.0    0.0     0.0  102.59
# 3    0  10300   57676.0   71027.0  DebtCon  NaN  19.0    0.0     0.0  157.52
# 4    0   9400   56508.0   78358.0  DebtCon  NaN  17.0    0.0     0.0  141.93
#
#    ninq  clno  debtinc
# 0   0.0  14.0   34.042
# 1   0.0  25.0   34.479
# 2   2.0   9.0   26.354
# 3   1.0  11.0   33.992
# 4   0.0  11.0   32.327

# %%
dataFrame.isna().sum()
# Out:
# bad          0
# loan         0
# mortdue    314
# value       64
# reason     147
# job        167
# yoj        312
# derog      427
# delinq     351
# clage      179
# ninq       303
# clno       133
# debtinc    767
# dtype: int64

# %%
target = dataFrame["bad"]
dataFrame = dataFrame.drop(columns=["bad"], axis = 1)
dataFrame.head()
# Out:
#     loan   mortdue     value   reason  job   yoj  derog  delinq   clage  ninq  \
# 0  81200   18834.0  108355.0  HomeImp  NaN  28.0    0.0     0.0  139.14   0.0
# 1  12600  103960.0  127384.0  DebtCon  NaN   2.0    0.0     0.0  129.02   0.0
# 2  18000   46865.0   61266.0  DebtCon  NaN   5.0    0.0     0.0  102.59   2.0
# 3  10300   57676.0   71027.0  DebtCon  NaN  19.0    0.0     0.0  157.52   1.0
# 4   9400   56508.0   78358.0  DebtCon  NaN  17.0    0.0     0.0  141.93   0.0
#
#    clno  debtinc
# 0  14.0   34.042
# 1  25.0   34.479
# 2   9.0   26.354
# 3  11.0   33.992
# 4  11.0   32.327

# %%
target.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
colsWithNaNs = []
for cols in range(len(dataFrame.columns)):
    if dataFrame.isna().sum()[cols] > 0:
        colsWithNaNs.append(dataFrame.columns[cols])
colsWithNaNs
# Out:
# ['mortdue',
#  'value',
#  'reason',
#  'job',
#  'yoj',
#  'derog',
#  'delinq',
#  'clage',
#  'ninq',
#  'clno',
#  'debtinc']

# %%
objectCols = []
for cols in colsWithNaNs:
    if dataFrame[cols].dtype.name == "object":
        objectCols.append(cols)
objectCols
# Out:
# ['reason', 'job']

# %%
imp = SimpleImputer(strategy="most_frequent")

# %%
print(imp.fit_transform(dataFrame[objectCols]))
# Out:
# [['HomeImp' 'Other']
#  ['DebtCon' 'Other']
#  ['DebtCon' 'Other']
#  ...
#  ['DebtCon' 'Self']
#  ['HomeImp' 'Self']
#  ['DebtCon' 'Self']]

# %%
temp = pd.DataFrame(imp.fit_transform(dataFrame[objectCols]),columns=objectCols,index=dataFrame.index)
temp.head()
# Out:
#     reason    job
# 0  HomeImp  Other
# 1  DebtCon  Other
# 2  DebtCon  Other
# 3  DebtCon  Other
# 4  DebtCon  Other

# %%
temp.isna().sum()
# Out:
# reason    0
# job       0
# dtype: int64

# %%
dataFrame = dataFrame.drop(columns=objectCols)
dataFrame[objectCols] = temp
dataFrame.head()
# Out:
#     loan   mortdue     value   yoj  derog  delinq   clage  ninq  clno  \
# 0  81200   18834.0  108355.0  28.0    0.0     0.0  139.14   0.0  14.0
# 1  12600  103960.0  127384.0   2.0    0.0     0.0  129.02   0.0  25.0
# 2  18000   46865.0   61266.0   5.0    0.0     0.0  102.59   2.0   9.0
# 3  10300   57676.0   71027.0  19.0    0.0     0.0  157.52   1.0  11.0
# 4   9400   56508.0   78358.0  17.0    0.0     0.0  141.93   0.0  11.0
#
#    debtinc   reason    job
# 0   34.042  HomeImp  Other
# 1   34.479  DebtCon  Other
# 2   26.354  DebtCon  Other
# 3   33.992  DebtCon  Other
# 4   32.327  DebtCon  Other

# %%
colsWithNaNs = list(set(colsWithNaNs) - set(objectCols))
colsWithNaNs
# Out:
# ['derog',
#  'yoj',
#  'value',
#  'mortdue',
#  'ninq',
#  'debtinc',
#  'clno',
#  'delinq',
#  'clage']

# %%
imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
temp = pd.DataFrame(imp.fit_transform(dataFrame[colsWithNaNs]),columns=colsWithNaNs,index=dataFrame.index)
temp.head()
# Out:
#    derog   yoj     value   mortdue  ninq  debtinc  clno  delinq   clage
# 0    0.0  28.0  108355.0   18834.0   0.0   34.042  14.0     0.0  139.14
# 1    0.0   2.0  127384.0  103960.0   0.0   34.479  25.0     0.0  129.02
# 2    0.0   5.0   61266.0   46865.0   2.0   26.354   9.0     0.0  102.59
# 3    0.0  19.0   71027.0   57676.0   1.0   33.992  11.0     0.0  157.52
# 4    0.0  17.0   78358.0   56508.0   0.0   32.327  11.0     0.0  141.93

# %%
dataFrame = dataFrame.drop(columns=colsWithNaNs)
dataFrame[colsWithNaNs] = temp
dataFrame.head()
# Out:
#     loan   reason    job  derog   yoj     value   mortdue  ninq  debtinc  \
# 0  81200  HomeImp  Other    0.0  28.0  108355.0   18834.0   0.0   34.042
# 1  12600  DebtCon  Other    0.0   2.0  127384.0  103960.0   0.0   34.479
# 2  18000  DebtCon  Other    0.0   5.0   61266.0   46865.0   2.0   26.354
# 3  10300  DebtCon  Other    0.0  19.0   71027.0   57676.0   1.0   33.992
# 4   9400  DebtCon  Other    0.0  17.0   78358.0   56508.0   0.0   32.327
#
#    clno  delinq   clage
# 0  14.0     0.0  139.14
# 1  25.0     0.0  129.02
# 2   9.0     0.0  102.59
# 3  11.0     0.0  157.52
# 4  11.0     0.0  141.93

# %%
dataFrame.boxplot()

# %%
dataFrame.shape, target.shape
# Out:
# ((3576, 12), (3576,))

# %%
dummyFeatures = pd.get_dummies(dataFrame[["job", "reason"]])
dataFrameWithDummies = pd.concat([dataFrame.drop(columns = ["job", "reason"]), dummyFeatures], axis = 1)
dataFrameWithDummies.head()
# Out:
#     loan  derog   yoj     value   mortdue  ninq  debtinc  clno  delinq  \
# 0  81200    0.0  28.0  108355.0   18834.0   0.0   34.042  14.0     0.0
# 1  12600    0.0   2.0  127384.0  103960.0   0.0   34.479  25.0     0.0
# 2  18000    0.0   5.0   61266.0   46865.0   2.0   26.354   9.0     0.0
# 3  10300    0.0  19.0   71027.0   57676.0   1.0   33.992  11.0     0.0
# 4   9400    0.0  17.0   78358.0   56508.0   0.0   32.327  11.0     0.0
#
#     clage  job_Mgr  job_Office  job_Other  job_ProfEx  job_Sales  job_Self  \
# 0  139.14        0           0          1           0          0         0
# 1  129.02        0           0          1           0          0         0
# 2  102.59        0           0          1           0          0         0
# 3  157.52        0           0          1           0          0         0
# 4  141.93        0           0          1           0          0         0
#
#    reason_DebtCon  reason_HomeImp
# 0               0               1
# ...

# %%
#dataFrameWithDummies = (dataFrameWithDummies - np.min(dataFrameWithDummies)) / (np.max(dataFrameWithDummies) - np.min(dataFrameWithDummies))
#dataFrameWithDummies.head()

# %%
xTrain, xTest, yTrain, yTest = train_test_split(dataFrameWithDummies, target, test_size = 0.33, random_state = 2019)

# %%
estimator = xgb.XGBClassifier()
param_grid = {
    'learning_rate': [0.005, 0.05],
    'min_child_weight': [0.003, 0.03, 0.3],
    'n_estimators':[100, 200, 300],
    'max_depth':[3, 4, 5, 6]
}
gbm = GridSearchCV(estimator, param_grid, cv=10,verbose=True, n_jobs=-1)
gbm.fit(xTrain, yTrain)
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   36.0s
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:  1.0min finished
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1),
#        fit_params=None, iid='warn', n_jobs=-1,
# ...

# %%
gbm.best_params_
# Out:
# {'learning_rate': 0.05,
#  'max_depth': 6,
#  'min_child_weight': 0.003,
#  'n_estimators': 300}

# %%
params = {'num_leaves': 491,
          'min_child_weight': 0.03,
          'min_data_in_leaf': 106,
          'objective': 'binary',
          'max_depth': -1,
          'learning_rate': 0.05,
          "boosting_type": "gbdt",
          "bagging_seed": 11,
          "metric": 'auc',
          "verbosity": -1,
          'random_state': 2019
         }

# %%
xgb_params = {'learning_rate': 0.05,
             'max_depth': 6,
             'min_child_weight': 0.003,
             'n_estimators': 300,
             'eval_metric':'auc'}

# %%
NFOLDS=10
SEED=71
kf = KFold(n_splits= NFOLDS, shuffle=True, random_state=2019)
oof_train = np.zeros((len(xTrain),))
oof_test = np.zeros((len(xTest),))
oof_test_skf = np.empty((NFOLDS, len(xTest)))
for i, (train_index, test_index) in enumerate(kf.split(xTrain, yTrain)):
    print('\nFold {}'.format(i + 1))
    x_tr = xTrain.iloc[train_index]
    y_tr = yTrain.iloc[train_index]
    y_te = yTrain.iloc[test_index]
    x_te = xTrain.iloc[test_index]
    
    d_train = xgb.DMatrix(x_tr, y_tr)
    d_valid = xgb.DMatrix(x_te, y_te)
    d_test = xgb.DMatrix(xTest)
                    
    watchlist = [(d_train, 'train'), (d_valid, 'valid')]
    clf = xgb.train(xgb_params, d_train, 5000,  watchlist, verbose_eval=50, early_stopping_rounds=100)
    
    oof_test_skf[i, :]    = clf.predict(d_test)

oof_test[:] = oof_test_skf.mean(axis=0)
# Out:
# Fold 1
# [01:53:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [0]	train-auc:0.910379	valid-auc:0.868526
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 100 rounds.
# [01:53:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [01:53:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [01:53:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [01:53:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [01:53:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [01:53:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# ...

# %%
yPred = np.round(oof_test)
ax = sns.heatmap(confusion_matrix(yTest, yPred), annot = True, fmt = "d")
ax.set_xlabel("Predicts")
ax.set_ylabel("Actuals")
# Out:
# Text(33.0, 0.5, 'Actuals')
